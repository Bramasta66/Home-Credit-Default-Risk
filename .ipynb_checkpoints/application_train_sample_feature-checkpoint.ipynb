# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)  # Tampilkan semua baris
pd.set_option('display.max_columns', None)  # Tampilkan semua kolom

# %%
filename = 'application_train'

# %%
df = pd.read_csv(filename + '.csv')
df.sample(5, random_state = 0)
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 42962       149741       1         Cash loans           F            N
# 227307      363290       0         Cash loans           M            N
# 290035      436006       0    Revolving loans           M            Y
# 239833      377703       0         Cash loans           M            Y
# 76427       188624       0         Cash loans           M            Y
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 42962                N             0          117000.0    417024.0
# 227307               Y             0          450000.0    640080.0
# 290035               Y             0          450000.0    900000.0
# 239833               N             1          360000.0   1125000.0
# 76427                Y             0          675000.0    835380.0
#
#         AMT_ANNUITY  AMT_GOODS_PRICE  NAME_TYPE_SUITE      NAME_INCOME_TYPE  \
# 42962       20191.5         360000.0  Spouse, partner               Working
# 227307      31261.5         450000.0    Unaccompanied  Commercial associate
# 290035      45000.0         900000.0    Unaccompanied  Commercial associate
# 239833      33025.5        1125000.0    Unaccompanied               Working
# 76427       42840.0         675000.0    Unaccompanied               Working
#
#                   NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# 42962               Incomplete higher               Married
# 227307               Higher education               Married
# 290035               Higher education  Single / not married
# 239833  Secondary / secondary special               Married
# 76427               Incomplete higher  Single / not married
#
#         NAME_HOUSING_TYPE  REGION_POPULATION_RELATIVE  DAYS_BIRTH  \
# 42962   House / apartment                    0.020246      -21774
# 227307  House / apartment                    0.046220      -18499
# 290035  House / apartment                    0.010643      -18084
# 239833  House / apartment                    0.018634      -12319
# 76427        With parents                    0.020713      -10151
#
#         DAYS_EMPLOYED  DAYS_REGISTRATION  DAYS_ID_PUBLISH  OWN_CAR_AGE  \
# 42962           -2125            -4611.0            -4653          NaN
# 227307          -2055            -3052.0            -2028          NaN
# 290035          -4159            -8525.0            -1616          4.0
# 239833          -2532           -12304.0            -4215          6.0
# 76427           -2516            -2789.0            -2834          6.0
#
#         FLAG_MOBIL  FLAG_EMP_PHONE  FLAG_WORK_PHONE  FLAG_CONT_MOBILE  \
# 42962            1               1                1                 1
# 227307           1               1                0                 1
# 290035           1               1                0                 1
# 239833           1               1                1                 1
# 76427            1               1                0                 1
#
#         FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  CNT_FAM_MEMBERS  \
# 42962            1           0  Security staff              2.0
# 227307           0           0        Laborers              2.0
# 290035           0           0        Managers              1.0
# 239833           0           0             NaN              3.0
# 76427            1           1         Drivers              1.0
#
#         REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY  \
# 42962                      3                            3
# 227307                     1                            1
# 290035                     2                            2
# 239833                     2                            2
# 76427                      3                            2
#
#        WEEKDAY_APPR_PROCESS_START  HOUR_APPR_PROCESS_START  \
# 42962                      FRIDAY                       13
# 227307                    TUESDAY                       13
# 290035                     SUNDAY                       14
# 239833                   THURSDAY                       15
# 76427                      MONDAY                        7
#
#         REG_REGION_NOT_LIVE_REGION  REG_REGION_NOT_WORK_REGION  \
# 42962                            0                           0
# 227307                           0                           0
# 290035                           0                           0
# 239833                           0                           1
# 76427                            0                           0
#
#         LIVE_REGION_NOT_WORK_REGION  REG_CITY_NOT_LIVE_CITY  \
# 42962                             0                       0
# 227307                            0                       0
# 290035                            0                       0
# 239833                            1                       0
# 76427                             0                       0
#
#         REG_CITY_NOT_WORK_CITY  LIVE_CITY_NOT_WORK_CITY  \
# 42962                        0                        0
# 227307                       0                        0
# 290035                       0                        0
# 239833                       1                        1
# 76427                        0                        0
#
#              ORGANIZATION_TYPE  EXT_SOURCE_1  EXT_SOURCE_2  EXT_SOURCE_3  \
# 42962                 Medicine      0.484936      0.182710      0.145543
# 227307  Business Entity Type 3      0.624574      0.669053      0.680139
# 290035            Construction           NaN      0.454279      0.173527
# 239833  Business Entity Type 3           NaN      0.688145      0.440058
# 76427        Transport: type 4           NaN      0.426409      0.081726
#
#         APARTMENTS_AVG  BASEMENTAREA_AVG  YEARS_BEGINEXPLUATATION_AVG  \
# 42962              NaN               NaN                          NaN
# 227307          0.3763            0.4482                       0.9950
# 290035          0.1113            0.0852                       0.9836
# 239833             NaN               NaN                          NaN
# 76427           0.0701            0.0846                       0.9732
#
#         YEARS_BUILD_AVG  COMMONAREA_AVG  ELEVATORS_AVG  ENTRANCES_AVG  \
# 42962               NaN             NaN            NaN            NaN
# 227307              NaN             NaN           0.48         0.2069
# 290035           0.7756          0.0189           0.12         0.1034
# 239833              NaN             NaN            NaN            NaN
# 76427            0.6328          0.0668           0.00         0.1379
#
#         FLOORSMAX_AVG  FLOORSMIN_AVG  LANDAREA_AVG  LIVINGAPARTMENTS_AVG  \
# 42962             NaN            NaN           NaN                   NaN
# 227307         0.6250            NaN        0.0347                   NaN
# 290035         0.3333         0.3750        0.0932                0.0908
# 239833            NaN            NaN           NaN                   NaN
# 76427          0.1667         0.2083        0.0433                0.0546
#
#         LIVINGAREA_AVG  NONLIVINGAPARTMENTS_AVG  NONLIVINGAREA_AVG  \
# 42962              NaN                      NaN                NaN
# 227307          0.4585                      NaN             0.0050
# 290035          0.1128                   0.0077             0.0047
# 239833             NaN                      NaN                NaN
# 76427           0.0512                   0.0116             0.0360
#
#         APARTMENTS_MODE  BASEMENTAREA_MODE  YEARS_BEGINEXPLUATATION_MODE  \
#
         0.0                        0.0
#
#         AMT_REQ_CREDIT_BUREAU_YEAR
# 42962                          3.0
# 227307                         1.0
# 290035                         0.0
# 239833                         1.0
# 76427                          2.0

# %%
# df['NAME_CONTRACT_TYPE'].value_counts().reset_index().head()

# %%
# df[df['SK_ID_CURR'] == 120860]

# %%
df_master = df.filter(items = df.columns[:16])
df_master.sample(5, random_state = 0)
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 42962       149741       1         Cash loans           F            N
# 227307      363290       0         Cash loans           M            N
# 290035      436006       0    Revolving loans           M            Y
# 239833      377703       0         Cash loans           M            Y
# 76427       188624       0         Cash loans           M            Y
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 42962                N             0          117000.0    417024.0
# 227307               Y             0          450000.0    640080.0
# 290035               Y             0          450000.0    900000.0
# 239833               N             1          360000.0   1125000.0
# 76427                Y             0          675000.0    835380.0
#
#         AMT_ANNUITY  AMT_GOODS_PRICE  NAME_TYPE_SUITE      NAME_INCOME_TYPE  \
# 42962       20191.5         360000.0  Spouse, partner               Working
# 227307      31261.5         450000.0    Unaccompanied  Commercial associate
# 290035      45000.0         900000.0    Unaccompanied  Commercial associate
# 239833      33025.5        1125000.0    Unaccompanied               Working
# 76427       42840.0         675000.0    Unaccompanied               Working
#
#                   NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  NAME_HOUSING_TYPE
# 42962               Incomplete higher               Married  House / apartment
# 227307               Higher education               Married  House / apartment
# 290035               Higher education  Single / not married  House / apartment
# 239833  Secondary / secondary special               Married  House / apartment
# 76427               Incomplete higher  Single / not married       With parents

# %%
list_item = []
for col in df_master.columns :
    list_item.append([col, df_master[col].dtype, df_master[col].count(), df_master[col].isna().sum(),
                      100 * df_master[col].isna().sum() / len(df_master[col]),
                      df_master[col].nunique(), df_master[col].unique()])
desc_df = pd.DataFrame(data = list_item, columns = ['feature', 'data_type', 'fill_num', 'null_num', 'null_persen', 'unique_num', 'unique_sample'])
desc_df
# Out:
#                 feature data_type  fill_num  null_num  null_persen  \
# 0            SK_ID_CURR     int64    307511         0     0.000000
# 1                TARGET     int64    307511         0     0.000000
# 2    NAME_CONTRACT_TYPE    object    307511         0     0.000000
# 3           CODE_GENDER    object    307511         0     0.000000
# 4          FLAG_OWN_CAR    object    307511         0     0.000000
# 5       FLAG_OWN_REALTY    object    307511         0     0.000000
# 6          CNT_CHILDREN     int64    307511         0     0.000000
# 7      AMT_INCOME_TOTAL   float64    307511         0     0.000000
# 8            AMT_CREDIT   float64    307511         0     0.000000
# 9           AMT_ANNUITY   float64    307499        12     0.003902
# 10      AMT_GOODS_PRICE   float64    307233       278     0.090403
# 11      NAME_TYPE_SUITE    object    306219      1292     0.420148
# 12     NAME_INCOME_TYPE    object    307511         0     0.000000
# 13  NAME_EDUCATION_TYPE    object    307511         0     0.000000
# 14   NAME_FAMILY_STATUS    object    307511         0     0.000000
# 15    NAME_HOUSING_TYPE    object    307511         0     0.000000
#
#     unique_num                                      unique_sample
# 0       307511  [100002, 100003, 100004, 100006, 100007, 10000...
# 1            2                                             [1, 0]
# 2            2                      [Cash loans, Revolving loans]
# 3            3                                        [M, F, XNA]
# 4            2                                             [N, Y]
# 5            2                                             [Y, N]
# 6           15  [0, 1, 2, 3, 4, 7, 5, 6, 8, 9, 11, 12, 10, 19,...
# 7         2548  [202500.0, 270000.0, 67500.0, 135000.0, 121500...
# 8         5603  [406597.5, 1293502.5, 135000.0, 312682.5, 5130...
# 9        13672  [24700.5, 35698.5, 6750.0, 29686.5, 21865.5, 2...
# 10        1002  [351000.0, 1129500.0, 135000.0, 297000.0, 5130...
# 11           7  [Unaccompanied, Family, Spouse, partner, Child...
# 12           8  [Working, State servant, Commercial associate,...
# 13           5  [Secondary / secondary special, Higher educati...
# 14           6  [Single / not married, Married, Civil marriage...
# 15           6  [House / apartment, Rented apartment, With par...
