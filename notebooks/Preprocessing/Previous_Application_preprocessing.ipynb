# %% [markdown]
# # Previous Application EDA

# %% [markdown]
# ### Import Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
from IPython.display import display

pd.set_option('display.max_rows', None)  # Tampilkan semua baris
pd.set_option('display.max_columns', None)  # Tampilkan semua kolom

# %%
prev_app = pd.read_csv('previous_application.csv')

# %% [markdown]
# ### Explore Previous Application

# %% [markdown]
# **Explanation of Features in the Previous Application Dataset :**</br>
# 0. SK_ID_PREV </br>
# ID of previous credit in Home credit related to loan in our sample. (One loan in our sample can have, or more previous loan applications in Home Credit, previous application could, but not necessarily have to lead to credit),hashed
# 1. SK_ID_CURR </br>
# ID of loan in our sample,hashed </br>
# 2. NAME_CONTRACT_TYPE </br>
# Contract product type (Cash loan, consumer loan [POS] ,...) of the previous application </br>
# 3. AMT_ANNUITY </br>
# Annuity of previous application </br>
# 4. AMT_APPLICATION </br>
# For how much credit did client ask on the previous application </br>
# 5. AMT_CREDIT </br>
# Final credit amount on the previous application. This differs from AMT_APPLICATION in a way that the AMT_APPLICATION is the amount for which the client initially applied for, but during our approval process he could have received different amount - AMT_CREDIT </br>
# 6. AMT_DOWN_PAYMENT </br>
# Down payment on the previous application </br>
# 7. AMT_GOODS_PRICE </br>
# Goods price of good that client asked for (if applicable) on the previous application </br>
# 8. WEEKDAY_APPR_PROCESS_START </br>
# On which day of the week did the client apply for previous application </br>
# 9. HOUR_APPR_PROCESS_START </br>
# Approximately at what day hour did the client apply for the previous application,rounded </br>
# 10. FLAG_LAST_APPL_PER_CONTRACT </br>
# Flag if it was last application for the previous contract. Sometimes by mistake of client or our clerk there could be more applications for one single contract </br>
# 11. NFLAG_LAST_APPL_IN_DAY </br>
# Flag if the application was the last application per day of the client. Sometimes clients apply for more applications a day. Rarely it could also be error in our system that one application is in the database twice </br>
# 12. NFLAG_MICRO_CASH </br>
# Flag Micro finance loan </br>
# 13. RATE_DOWN_PAYMENT </br>
# Down payment rate normalized on previous credit,normalized </br>
# 14. RATE_INTEREST_PRIMARY </br>
# Interest rate normalized on previous credit,normalized </br>
# 15. RATE_INTEREST_PRIVILEGED </br>
# Interest rate normalized on previous credit,normalized </br>
# 16. NAME_CASH_LOAN_PURPOSE </br>
# Purpose of the cash loan </br>
# 17. NAME_CONTRACT_STATUS </br>
# Contract status (approved, cancelled, ...) of previous application </br>
# 18. DAYS_DECISION </br>
# Relative to current application when was the decision about previous application made,time only relative to the application </br>
# 19. NAME_PAYMENT_TYPE </br>
# Payment method that client chose to pay for the previous application </br>
# 20. CODE_REJECT_REASON </br>
# Why was the previous application rejected </br>
# 21. NAME_TYPE_SUITE <
# /br>
# Who accompanied client when applying for the previous application </br>
# 22. NAME_CLIENT_TYPE </br>
# Was the client old or new client when applying for the previous application </br>
# 23. NAME_GOODS_CATEGORY </br>
# What kind of goods did the client apply for in the previous application </br>
# 24. NAME_PORTFOLIO </br>
# Was the previous application for CASH, POS, CAR, …, </br>
# 25. NAME_PRODUCT_TYPE </br>
# Was the previous application x-sell o walk-in </br>
# 26. CHANNEL_TYPE </br>
# Through which channel we acquired the client on the previous application </br>
# 27. SELLERPLACE_AREA </br>
# Selling area of seller place of the previous application </br>
# 28. NAME_SELLER_INDUSTRY </br>
# The industry of the seller </br>
# 29. CNT_PAYMENT </br>
# Term of previous credit at application of the previous application </br>
# 30. NAME_YIELD_GROUP </br>
# Grouped interest rate into small medium and high of the previous application,grouped </br>
# 31. PRODUCT_COMBINATION </br>
# Detailed product combination of the previous application </br>
# 32. DAYS_FIRST_DRAWING </br>
# Relative to application date of current application when was the first disbursement of the previous application,time only relative to the application </br>
# 33. DAYS_FIRST_DUE </br>
# Relative to application date of current application when was the first due supposed to be of the previous application,time only relative to the application </br>
# 34. DAYS_LAST_DUE_ST_VERSION </br>
# Relative to application date of current application when was the first due of the previous application,time only relative to the application </br>
# 35. DAYS_LAST_DUE </br>
# Relative to application date of current application when was the last due date of the previous application,time only relative to the application </br>
# 36. DAYS_TERMINATION </br>
# Relative to application date of current application when was the expected termination of the previous application,time only relative to the application </br>
# 37. NFLAG_INSUREapplication</br>L </br>
# Did the client requested insurance during the previous application
# ce during the previous application,
#
# nce during the previous application,

# %%
prev_app.sample(10)
# Out:
#          SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  \
# 582662      1912857      324135     Consumer loans     5198.130
# 1007640     1953444      311052         Cash loans          NaN
# 1008801     1563972      358132         Cash loans    30327.705
# 1382552     1628644      343339         Cash loans          NaN
# 1212595     2406288      209618     Consumer loans     9136.260
# 1494158     1168344      395278         Cash loans    55380.600
# 1126477     1834283      310752         Cash loans          NaN
# 686732      2745926      362072         Cash loans    27359.730
# 1358717     2505338      208237     Consumer loans     4531.140
# 1121607     2249227      453823    Revolving loans    12375.000
#
#          AMT_APPLICATION  AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 582662           27220.5     28566.0               0.0          27220.5
# 1007640              0.0         0.0               NaN              NaN
# ...

# %%
prev_app.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1670214 entries, 0 to 1670213
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   SK_ID_PREV                   1670214 non-null  int64
#  1   SK_ID_CURR                   1670214 non-null  int64
#  2   NAME_CONTRACT_TYPE           1670214 non-null  object
#  3   AMT_ANNUITY                  1297979 non-null  float64
#  4   AMT_APPLICATION              1670214 non-null  float64
#  5   AMT_CREDIT                   1670213 non-null  float64
#  6   AMT_DOWN_PAYMENT             774370 non-null   float64
#  7   AMT_GOODS_PRICE              1284699 non-null  float64
#  8   WEEKDAY_APPR_PROCESS_START   1670214 non-null  object
#  9   HOUR_APPR_PROCESS_START      1670214 non-null  int64
#  10  FLAG_LAST_APPL_PER_CONTRACT  1670214 non-null  object
#  11  NFLAG_LAST_APPL_IN_DAY       1670214 non-null  int64
# ...

# %% [markdown]
# **Statistical values of the numerical features**

# %%
prev_app.describe()
# Out:
#          SK_ID_PREV    SK_ID_CURR   AMT_ANNUITY  AMT_APPLICATION  \
# count  1.670214e+06  1.670214e+06  1.297979e+06     1.670214e+06
# mean   1.923089e+06  2.783572e+05  1.595512e+04     1.752339e+05
# std    5.325980e+05  1.028148e+05  1.478214e+04     2.927798e+05
# min    1.000001e+06  1.000010e+05  0.000000e+00     0.000000e+00
# 25%    1.461857e+06  1.893290e+05  6.321780e+03     1.872000e+04
# 50%    1.923110e+06  2.787145e+05  1.125000e+04     7.104600e+04
# 75%    2.384280e+06  3.675140e+05  2.065842e+04     1.803600e+05
# max    2.845382e+06  4.562550e+05  4.180581e+05     6.905160e+06
#
#          AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# count  1.670213e+06      7.743700e+05     1.284699e+06
# mean   1.961140e+05      6.697402e+03     2.278473e+05
# std    3.185746e+05      2.092150e+04     3.153966e+05
# min    0.000000e+00     -9.000000e-01     0.000000e+00
# 25%    2.416050e+04      0.000000e+00     5.084100e+04
# ...

# %% [markdown]
# **Statistical descriptive of all the feature**

# %%
list_item_ap = []
for col in prev_app.columns:
    list_item_ap.append([
        col,
        prev_app[col].dtype,
        prev_app[col].count(),
        prev_app[col].isna().sum(),
        100*prev_app[col].isna().sum() / len(prev_app[col]),
        prev_app[col].nunique(),
        prev_app[col].unique()
    ])

desc_df = pd.DataFrame(data = list_item_ap, columns =[
    'feature', 'data_type', 'fill_num', 'null_num', 'null_persen', 'unique_num', 'unique_sample'
])

desc_df
# Out:
#                         feature data_type  fill_num  null_num  null_persen  \
# 0                    SK_ID_PREV     int64   1670214         0     0.000000
# 1                    SK_ID_CURR     int64   1670214         0     0.000000
# 2            NAME_CONTRACT_TYPE    object   1670214         0     0.000000
# 3                   AMT_ANNUITY   float64   1297979    372235    22.286665
# 4               AMT_APPLICATION   float64   1670214         0     0.000000
# 5                    AMT_CREDIT   float64   1670213         1     0.000060
# 6              AMT_DOWN_PAYMENT   float64    774370    895844    53.636480
# 7               AMT_GOODS_PRICE   float64   1284699    385515    23.081773
# 8    WEEKDAY_APPR_PROCESS_START    object   1670214         0     0.000000
# 9       HOUR_APPR_PROCESS_START     int64   1670214         0     0.000000
# 10  FLAG_LAST_APPL_PER_CONTRACT    object   1670214         0     0.000000
# ...

# %% [markdown]
# **Check if there are any features with duplicate values**

# %%
def check_duplicates(prev_app):
    data_duplikat = prev_app[prev_app.duplicated()]
    if not data_duplikat.empty:
        print(f"Ada {len(data_duplikat)} baris yang duplikat.")
        print("\nBaris yang duplikat:")
        print(data_duplikat)
    else:
        print("Tidak ada data yang duplikat di dataset.")
check_duplicates(prev_app)
# Out:
# Tidak ada data yang duplikat di dataset.

# %% [markdown]
# **Check if there are any features with missing values:**

# %%
prev_app['NAME_TYPE_SUITE'].value_counts()
# Out:
# NAME_TYPE_SUITE
# Unaccompanied      508970
# Family             213263
# Spouse, partner     67069
# Children            31566
# Other_B             17624
# Other_A              9077
# Group of people      2240
# Name: count, dtype: int64

# %%
prev_app['PRODUCT_COMBINATION'].value_counts()
# Out:
# PRODUCT_COMBINATION
# Cash                              285990
# POS household with interest       263622
# POS mobile with interest          220670
# Cash X-Sell: middle               143883
# Cash X-Sell: low                  130248
# Card Street                       112582
# POS industry with interest         98833
# POS household without interest     82908
# Card X-Sell                        80582
# Cash Street: high                  59639
# Cash X-Sell: high                  59301
# Cash Street: middle                34658
# Cash Street: low                   33834
# POS mobile without interest        24082
# POS other with interest            23879
# POS industry without interest      12602
# POS others without interest         2555
# Name: count, dtype: int64

# %%
def check_missing_values(prev_app):
    missing_values = prev_app.isnull().sum()
    if missing_values.any():
        print("Kolom yang terdapat missing value:")
        print(missing_values[missing_values > 0])
    else:
        print("Tidak ada missing value di dataset.")
check_missing_values(prev_app)
# Out:
# Kolom yang terdapat missing value:
# AMT_ANNUITY                   372235
# AMT_CREDIT                         1
# AMT_DOWN_PAYMENT              895844
# AMT_GOODS_PRICE               385515
# RATE_DOWN_PAYMENT             895844
# RATE_INTEREST_PRIMARY        1664263
# RATE_INTEREST_PRIVILEGED     1664263
# NAME_TYPE_SUITE               820405
# CNT_PAYMENT                   372230
# PRODUCT_COMBINATION              346
# DAYS_FIRST_DRAWING            673065
# DAYS_FIRST_DUE                673065
# DAYS_LAST_DUE_1ST_VERSION     673065
# DAYS_LAST_DUE                 673065
# DAYS_TERMINATION              673065
# NFLAG_INSURED_ON_APPROVAL     673065
# dtype: int64

# %%
missing_percentage = prev_app[['AMT_ANNUITY', 'AMT_CREDIT', 'AMT_DOWN_PAYMENT', 'AMT_GOODS_PRICE', 'RATE_DOWN_PAYMENT', 'RATE_INTEREST_PRIMARY',
                               'RATE_INTEREST_PRIVILEGED', 'NAME_TYPE_SUITE', 'CNT_PAYMENT', 'PRODUCT_COMBINATION', 'DAYS_FIRST_DRAWING', 'DAYS_FIRST_DUE',
                               'DAYS_LAST_DUE_1ST_VERSION', 'DAYS_LAST_DUE', 'DAYS_TERMINATION', 'NFLAG_INSURED_ON_APPROVAL']].isnull().mean() * 100
print(missing_percentage)
# Out:
# AMT_ANNUITY                  22.286665
# AMT_CREDIT                    0.000060
# AMT_DOWN_PAYMENT             53.636480
# AMT_GOODS_PRICE              23.081773
# RATE_DOWN_PAYMENT            53.636480
# RATE_INTEREST_PRIMARY        99.643698
# RATE_INTEREST_PRIVILEGED     99.643698
# NAME_TYPE_SUITE              49.119754
# CNT_PAYMENT                  22.286366
# PRODUCT_COMBINATION           0.020716
# DAYS_FIRST_DRAWING           40.298129
# DAYS_FIRST_DUE               40.298129
# DAYS_LAST_DUE_1ST_VERSION    40.298129
# DAYS_LAST_DUE                40.298129
# DAYS_TERMINATION             40.298129
# NFLAG_INSURED_ON_APPROVAL    40.298129
# dtype: float64

# %% [markdown]
# ### Univariate Analysis

# %%
# Identify numerical and categorical columns
numerical_columns = prev_app.select_dtypes(include=['int64', 'float64']).columns
categorical_columns = prev_app.select_dtypes(include=['object']).columns

print("Numerical Columns: ", numerical_columns)
print("Categorical Columns: ", categorical_columns)
# Out:
# Numerical Columns:  Index(['SK_ID_PREV', 'SK_ID_CURR', 'AMT_ANNUITY', 'AMT_APPLICATION',
#        'AMT_CREDIT', 'AMT_DOWN_PAYMENT', 'AMT_GOODS_PRICE',
#        'HOUR_APPR_PROCESS_START', 'NFLAG_LAST_APPL_IN_DAY',
#        'RATE_DOWN_PAYMENT', 'RATE_INTEREST_PRIMARY',
#        'RATE_INTEREST_PRIVILEGED', 'DAYS_DECISION', 'SELLERPLACE_AREA',
#        'CNT_PAYMENT', 'DAYS_FIRST_DRAWING', 'DAYS_FIRST_DUE',
#        'DAYS_LAST_DUE_1ST_VERSION', 'DAYS_LAST_DUE', 'DAYS_TERMINATION',
#        'NFLAG_INSURED_ON_APPROVAL'],
#       dtype='object')
# Categorical Columns:  Index(['NAME_CONTRACT_TYPE', 'WEEKDAY_APPR_PROCESS_START',
#        'FLAG_LAST_APPL_PER_CONTRACT', 'NAME_CASH_LOAN_PURPOSE',
#        'NAME_CONTRACT_STATUS', 'NAME_PAYMENT_TYPE', 'CODE_REJECT_REASON',
#        'NAME_TYPE_SUITE', 'NAME_CLIENT_TYPE', 'NAME_GOODS_CATEGORY',
#        'NAME_PORTFOLIO', 'NAME_PRODUCT_TYPE', 'CHANNEL_TYPE',
#        'NAME_SELLER_INDUSTRY', 'NAME_YIELD_GROUP', 'PRODUCT_COMBINATION'],
# ...

# %% [markdown]
# **Numerical Analysis**

# %%
# Boxplot untuk mengetahui berapa banyak dan berapa jauh outlier di setiap kolom
plt.figure(figsize=(16, 20))
for i, col in enumerate(numerical_columns):
    plt.subplot(len(numerical_columns)//2+1, 2, i+1)
    sns.boxplot(data=prev_app, x=col)
    plt.title(f'Boxplot of {col}')
    plt.tight_layout()
plt.show()

# %% [markdown]
# **Categorical Analysis**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# List kolom kategorikal yang ingin dianalisis dari prev_app
categorical = ['NAME_CONTRACT_STATUS', 'NAME_CLIENT_TYPE', 'NAME_GOODS_CATEGORY','NAME_YIELD_GROUP', 'NAME_CASH_LOAN_PURPOSE', 'CODE_REJECT_REASON']

# Plot count plots untuk setiap kolom  # Mengatur ukuran plot
plt.figure(figsize=(16, 16))  
for i, col in enumerate(categorical):
    plt.subplot(3, 3, i+1)  # Membuat grid 3 baris dan 3 kolom
    sns.countplot(data=prev_app, x=col, order=prev_app[col].value_counts().index)
    plt.xticks(rotation=90) 
    plt.title(f'Distribution of {col}')
    plt.tight_layout()

plt.show()

# %% [markdown]
# ### Multivariate Analysis

# %%
# Import dataset yang dijadikan acuan, yaitu application_train
df_train = pd.read_csv('application_train.csv')

# Merge atau gabungkan dataset, tetapi hanya dengan kolom Target
merged_df = pd.merge(prev_app, df_train[['SK_ID_CURR', 'TARGET']], on='SK_ID_CURR', how='left')

merged_df.sample(10)
# Out:
#          SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  \
# 190197      2344533      210387         Cash loans     8669.385
# 1554844     2093635      209601         Cash loans    41062.500
# 1016946     1762279      177408     Consumer loans     2181.240
# 820412      1957448      197430         Cash loans    40389.030
# 257609      1892864      388181         Cash loans    23254.380
# 1088083     1926861      339353     Consumer loans     3336.300
# 289074      1562906      380499     Consumer loans    11134.665
# 603652      2214867      213954     Consumer loans     3845.115
# 692171      1776511      360533     Consumer loans     8229.375
# 864786      1436671      425227         Cash loans    48483.630
#
#          AMT_APPLICATION  AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 190197           67500.0     71955.0               NaN          67500.0
# 1554844        1350000.0   1350000.0               NaN        1350000.0
# ...

# %% [markdown]
# **Correlation Heatmap**

# %%
# Kolom data numerik yang sudah dimerge
num_col_merge = merged_df.select_dtypes(include=['int64', 'float64']).columns

# Korelasi antar feature yang disertai feature target
correlation_matrix = merged_df[num_col_merge].corr()

# Heatmap figure
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap of prev_app Numerical Features')
plt.show()

# %%
# Buat pivot table untuk mendapatkan jumlah masing-masing kategori
pivot_table = merged_df.pivot_table(index='NAME_CONTRACT_STATUS', columns='TARGET', aggfunc='size')

# Hitung jumlah total untuk setiap kategori dan urutkan
pivot_table['Total'] = pivot_table.sum(axis=1)
pivot_table_sorted = pivot_table.sort_values(by='Total', ascending=False)

# Buat stacked bar plot dengan urutan yang telah diatur
pivot_table_sorted.drop('Total', axis=1).plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Stacked Bar Plot of Contract Status by Target (Sorted by Total)')
plt.xticks(rotation=0)
plt.ylabel('Count')
plt.show()

# %%
# Buat pivot table untuk mendapatkan jumlah masing-masing kategori
pivot_table2 = merged_df.pivot_table(index='NAME_CLIENT_TYPE', columns='TARGET', aggfunc='size')

# Hitung jumlah total untuk setiap kategori dan urutkan
pivot_table2['Total'] = pivot_table2.sum(axis=1)
pivot_table2_sorted = pivot_table2.sort_values(by='Total', ascending=False)

# Buat stacked bar plot dengan urutan yang telah diatur
pivot_table2_sorted.drop('Total', axis=1).plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Stacked Bar Plot of Client Type by Target (Sorted by Total)')
plt.xticks(rotation=0)
plt.ylabel('Count')
plt.show()

# %%
# Buat pivot table untuk mendapatkan jumlah masing-masing kategori
pivot_table3 = merged_df.pivot_table(index='NAME_GOODS_CATEGORY', columns='TARGET', aggfunc='size')

# Hitung jumlah total untuk setiap kategori dan urutkan
pivot_table3['Total'] = pivot_table3.sum(axis=1)
pivot_table3_sorted = pivot_table3.sort_values(by='Total', ascending=False)

# Buat stacked bar plot dengan urutan yang telah diatur
pivot_table3_sorted.drop('Total', axis=1).plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Stacked Bar Plot of Goods Category by Target (Sorted by Total)')
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.show()

# %%
# Buat pivot table untuk mendapatkan jumlah masing-masing kategori
pivot_table4 = merged_df.pivot_table(index='NAME_YIELD_GROUP', columns='TARGET', aggfunc='size')

# Hitung jumlah total untuk setiap kategori dan urutkan
pivot_table4['Total'] = pivot_table4.sum(axis=1)
pivot_table4_sorted = pivot_table4.sort_values(by='Total', ascending=False)

# Buat stacked bar plot dengan urutan yang telah diatur
pivot_table4_sorted.drop('Total', axis=1).plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Stacked Bar Plot of Yield Group by Target (Sorted by Total)')
plt.xticks(rotation=0)
plt.ylabel('Count')
plt.show()

# %%
# Buat pivot table untuk mendapatkan jumlah masing-masing kategori
pivot_table5 = merged_df.pivot_table(index='NAME_CASH_LOAN_PURPOSE', columns='TARGET', aggfunc='size')

# Hitung jumlah total untuk setiap kategori dan urutkan
pivot_table5['Total'] = pivot_table5.sum(axis=1)
pivot_table5_sorted = pivot_table5.sort_values(by='Total', ascending=False)

# Buat stacked bar plot dengan urutan yang telah diatur
pivot_table5_sorted.drop('Total', axis=1).plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Stacked Bar Plot of Cash Loan Purpose by Target (Sorted by Total)')
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.show()

# %%
# Buat pivot table untuk mendapatkan jumlah masing-masing kategori
pivot_table6 = merged_df.pivot_table(index='CODE_REJECT_REASON', columns='TARGET', aggfunc='size')

# Hitung jumlah total untuk setiap kategori dan urutkan
pivot_table6['Total'] = pivot_table6.sum(axis=1)
pivot_table6_sorted = pivot_table6.sort_values(by='Total', ascending=False)

# Buat stacked bar plot dengan urutan yang telah diatur
pivot_table6_sorted.drop('Total', axis=1).plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Stacked Bar Plot of Reject Reason by Target (Sorted by Total)')
plt.xticks(rotation=0)
plt.ylabel('Count')
plt.show()

# %%
pd.crosstab(prev_app['NAME_CLIENT_TYPE'], prev_app['NAME_CONTRACT_STATUS'], normalize='index').plot(kind='bar', stacked=True)
plt.title('Approval Status by Client Type')
plt.ylabel('Proportion')
plt.xticks(rotation=0)
plt.show()

# %%
sns.countplot(data=prev_app, x='NAME_CONTRACT_TYPE', hue='NAME_CONTRACT_STATUS', order=prev_app['NAME_CONTRACT_TYPE'].value_counts().index)
plt.title('Contract Status by Contract Type')
plt.xticks(rotation=45)
plt.show()

# %%
# Menghitung jumlah persetujuan berdasarkan kelompok barang
approval_rate = prev_app[prev_app['NAME_CONTRACT_STATUS'] == 'Approved'].groupby('NAME_GOODS_CATEGORY').size().reset_index(name='count')

# Mengurutkan dari yang paling besar
approval_rate_sorted = approval_rate.sort_values(by='count', ascending=False)

plt.figure(figsize=(12, 8))
sns.barplot(data=approval_rate_sorted, x='count', y='NAME_GOODS_CATEGORY')
plt.title('Tingkat Persetujuan Berdasarkan Kelompok Barang yang Dibeli')
plt.xlabel('Jumlah Persetujuan')
plt.ylabel('Kelompok Barang yang Dibeli')
plt.show()

# %% [markdown]
# ## Pre-Processing

# %% [markdown]
# ### Data Cleansing

# %% [markdown]
# #### A. Handle Missing Values

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# Filling missing values in numerical features with median
prev_app['AMT_ANNUITY'].fillna(prev_app['AMT_ANNUITY'].median(), inplace=True)
prev_app['AMT_CREDIT'].fillna(prev_app['AMT_CREDIT'].median(), inplace=True)
prev_app['AMT_DOWN_PAYMENT'].fillna(prev_app['AMT_DOWN_PAYMENT'].median(), inplace=True)
prev_app['AMT_GOODS_PRICE'].fillna(prev_app['AMT_GOODS_PRICE'].median(), inplace=True)
prev_app['RATE_DOWN_PAYMENT'].fillna(prev_app['RATE_DOWN_PAYMENT'].median(), inplace=True)
prev_app['RATE_INTEREST_PRIMARY'].fillna(prev_app['RATE_DOWN_PAYMENT'].median(), inplace=True)
prev_app['RATE_INTEREST_PRIVILEGED'].fillna(prev_app['RATE_DOWN_PAYMENT'].median(), inplace=True)
prev_app['CNT_PAYMENT'].fillna(prev_app['CNT_PAYMENT'].median(), inplace=True)
prev_app['DAYS_FIRST_DRAWING'].fillna(prev_app['DAYS_FIRST_DRAWING'].median(), inplace=True)
prev_app['DAYS_FIRST_DUE'].fillna(prev_app['DAYS_FIRST_DUE'].median(), inplace=True)
prev_app['DAYS_LAST_DUE_1ST_VERSION'].fillna(prev_app['DAYS_LAST_DUE_1ST_VERSION'].median(), inplace=True)
prev_app['DAYS_LAST_DUE'].fillna(prev_app['DAYS_LAST_DUE'].median(), inplace=True)
prev_app['DAYS_TERMINATION'].fillna(prev_app['DAYS_TERMINATION'].median(), inplace=True)

# Filling missing value in features with 0
prev_app['NFLAG_INSURED_ON_APPROVAL'] = prev_app['NFLAG_INSURED_ON_APPROVAL'].fillna(0)

prev_app.sample(10)
# Out:
#          SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  \
# 934627      1394999      130478         Cash loans    23112.360
# 1161674     2330964      344344     Consumer loans     2719.890
# 28582       1363033      337462     Consumer loans     6733.350
# 830757      1989573      257776         Cash loans    32478.435
# 943313      1662689      216708         Cash loans    11250.000
# 1109842     2011225      341908         Cash loans    28711.080
# 234745      2482891      320657         Cash loans    25198.650
# 1366856     1348163      410372         Cash loans    11250.000
# 1571021     2370559      116869    Revolving loans    16875.000
# 140708      1623367      254153     Consumer loans    31998.375
#
#          AMT_APPLICATION  AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 934627          495000.0    712395.0            1638.0         495000.0
# 1161674          22455.0     22684.5            4500.0          22455.0
# ...

# %%
#Filling missing values in categorical features
prev_app['NAME_TYPE_SUITE'] = prev_app['NAME_TYPE_SUITE'].fillna('Unaccompanied')
prev_app['PRODUCT_COMBINATION'] = prev_app['PRODUCT_COMBINATION'].fillna(prev_app['PRODUCT_COMBINATION'].mode()[0])

#Check missing values
check_missing_values(prev_app)
# Out:
# Tidak ada missing value di dataset.

# %% [markdown]
# #### B. Handle Duplicated Data

# %% [markdown]
# Tidak perlu handle duplicated data karena tidak ada data yang duplicate.

# %% [markdown]
# #### C. Handle Outliers

# %% [markdown]
# Handle Outliers menggunakan IQR karena data memiliki banyak outliers ekstrem. Handling outliers digunakan untuk data numerikal murni.
# Pertama-tama definisikan terlebih dahulu kolom numerikal, kategorikal linear, kategorikal non-linear, dan kolom yang akan didelete untuk memudahkan proses selanjutnya.

# %%
#data numerikal murni
num_col = prev_app[['AMT_ANNUITY', 'AMT_APPLICATION', 'AMT_CREDIT', 'AMT_DOWN_PAYMENT', 'AMT_GOODS_PRICE',
           'DAYS_DECISION', 'DAYS_FIRST_DRAWING', 'DAYS_FIRST_DUE', 'DAYS_LAST_DUE_1ST_VERSION', 'DAYS_LAST_DUE', 'DAYS_TERMINATION']]

#data kategori yang dibuat numerikal
#cats_lin = prev_app[['HOUR_APPR_PROCESS_START', 'NFLAG_LAST_APPL_IN_DAY', 'SELLERPLACE_AREA', 'CNT_PAYMENT', 'NFLAG_INSURED_ON_APPROVAL']]

#data kategori
#cats_nonlin = prev_app[['NAME_CONTRACT_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'FLAG_LAST_APPL_PER_CONTRACT', 'NAME_CASH_LOAN_PURPOSE', 'NAME_CONTRACT_STATUS', 'NAME_PAYMENT_TYPE', 'CODE_REJECT_REASON','NAME_TYPE_SUITE', 'NAME_CLIENT_TYPE', 'NAME_GOODS_CATEGORY', 'NAME_PORTFOLIO', 'NAME_PRODUCT_TYPE','CHANNEL_TYPE', 'NAME_SELLER_INDUSTRY', 'NAME_YIELD_GROUP', 'PRODUCT_COMBINATION']]

#data kolom yang berupa normalized akan dihapus
#col_remove = prev_app[['RATE_DOWN_PAYMENT', 'RATE_INTEREST_PRIMARY', 'RATE_INTEREST_PRIVILEGED']]

# %%
# Hitung Q1 dan Q3
Q1 = num_col.quantile(0.25)
Q3 = num_col.quantile(0.75)
IQR = Q3 - Q1

# Filter outliers menggunakan IQR
prev_app2 = prev_app[~((num_col < (Q1 - 1.5 * IQR)) | (num_col > (Q3 + 1.5 * IQR))).any(axis=1)]

print("Data setelah menghapus outliers menggunakan IQR:")
print(prev_app2.info())
# Out:
# Data setelah menghapus outliers menggunakan IQR:
# <class 'pandas.core.frame.DataFrame'>
# Index: 536201 entries, 5 to 1670212
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   SK_ID_PREV                   536201 non-null  int64
#  1   SK_ID_CURR                   536201 non-null  int64
#  2   NAME_CONTRACT_TYPE           536201 non-null  object
#  3   AMT_ANNUITY                  536201 non-null  float64
#  4   AMT_APPLICATION              536201 non-null  float64
#  5   AMT_CREDIT                   536201 non-null  float64
#  6   AMT_DOWN_PAYMENT             536201 non-null  float64
#  7   AMT_GOODS_PRICE              536201 non-null  float64
#  8   WEEKDAY_APPR_PROCESS_START   536201 non-null  object
#  9   HOUR_APPR_PROCESS_START      536201 non-null  int64
#  10  FLAG_LAST_APPL_PER_CONTRACT  536201 non-null  object
# ...

# %%
#Check kembali missing value setelah handling outlier
check_missing_values(prev_app2)
# Out:
# Tidak ada missing value di dataset.

# %% [markdown]
# #### D. Feature Transformation

# %% [markdown]
# Sebelum transformasi data numerik, dilihat terlebih dahulu distribusi data untuk menentukan metode yang tepat.

# %%
#Numerical features from latest data
num_col2 = prev_app2[['AMT_ANNUITY', 'AMT_APPLICATION', 'AMT_CREDIT', 'AMT_DOWN_PAYMENT', 'AMT_GOODS_PRICE',
           'DAYS_DECISION', 'DAYS_FIRST_DRAWING', 'DAYS_FIRST_DUE', 'DAYS_LAST_DUE_1ST_VERSION', 'DAYS_LAST_DUE', 'DAYS_TERMINATION']]

# Determine the distribution type of each numeric column
distribution_types = {}

for col in num_col2.columns:
    skewness = num_col2[col].skew()
    if skewness > 0.5:
        distribution_types[col] = 'Right-skewed'
    elif skewness < -0.5:
        distribution_types[col] = 'Left-skewed'
    else:
        distribution_types[col] = 'Normal'

# Display the results
for col, dist_type in distribution_types.items():
    print(f'{col}: {dist_type}')
# Out:
# AMT_ANNUITY: Right-skewed
# AMT_APPLICATION: Right-skewed
# AMT_CREDIT: Right-skewed
# AMT_DOWN_PAYMENT: Normal
# AMT_GOODS_PRICE: Right-skewed
# DAYS_DECISION: Left-skewed
# DAYS_FIRST_DRAWING: Normal
# DAYS_FIRST_DUE: Normal
# DAYS_LAST_DUE_1ST_VERSION: Normal
# DAYS_LAST_DUE: Normal
# DAYS_TERMINATION: Left-skewed

# %%
# Buat figure dan axes untuk 11 subplot
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(20, 15))  # 4 baris dan 3 kolom subplot
axes = axes.flatten()  # Ratakan array 2D menjadi 1D agar lebih mudah diakses

# Loop melalui setiap kolom dan plot histogram
for i, col in enumerate(num_col2):
    if i >= len(axes):  # Pastikan tidak melebihi jumlah axes yang tersedia
        break
    mean_val = num_col2[col].mean()
    median_val = num_col2[col].median()

    sns.histplot(num_col2[col], ax=axes[i], bins=20, kde=True, label=col)
    axes[i].axvline(x=mean_val, color='g', linestyle='dashed', label='Mean')
    axes[i].axvline(x=median_val, color='y', linestyle='dashed', label='Median')
    axes[i].legend()
    axes[i].set_title(f'Histogram of {col}')

# Hapus subplot yang tidak terpakai (jika ada)
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# Atur layout agar tidak saling tumpang tindih
plt.tight_layout()
plt.show()

# %%
#Lakukan transformasi dengan MinMaxScaler pada data yang Left-skewed
from sklearn.preprocessing import MinMaxScaler

prev_app2.loc[:, 'DAYS_DECISION'] = MinMaxScaler().fit_transform(prev_app2['DAYS_DECISION'].values.reshape(len(prev_app2), 1))
prev_app2.loc[:, 'DAYS_TERMINATION'] = MinMaxScaler().fit_transform(prev_app2['DAYS_FIRST_DRAWING'].values.reshape(len(prev_app2), 1))

# %%
#Lakukan strandardized pada data yang berdistribusi Normal
from sklearn.preprocessing import StandardScaler
prev_app2.loc[:, 'AMT_DOWN_PAYMENT'] = StandardScaler().fit_transform(prev_app2['AMT_DOWN_PAYMENT'].values.reshape(len(prev_app2), 1))
prev_app2.loc[:, 'DAYS_FIRST_DRAWING'] = StandardScaler().fit_transform(prev_app2['DAYS_FIRST_DRAWING'].values.reshape(len(prev_app2), 1))
prev_app2.loc[:, 'DAYS_FIRST_DUE'] = StandardScaler().fit_transform(prev_app2['DAYS_FIRST_DUE'].values.reshape(len(prev_app2), 1))
prev_app2.loc[:, 'DAYS_LAST_DUE_1ST_VERSION'] = StandardScaler().fit_transform(prev_app2['DAYS_LAST_DUE_1ST_VERSION'].values.reshape(len(prev_app2), 1))
prev_app2.loc[:, 'DAYS_LAST_DUE'] = StandardScaler().fit_transform(prev_app2['DAYS_LAST_DUE'].values.reshape(len(prev_app2), 1))

# %%
#Lakukan transformasi dengan Log Transformation pada data yang Right-skewed
#np.log1p() calculates the natural logarithm of (1 + x), which can handle zero values:
prev_app2.loc[:, 'AMT_ANNUITY'] = np.log1p(prev_app2['AMT_ANNUITY'])
prev_app2.loc[:, 'AMT_APPLICATION'] = np.log1p(prev_app2['AMT_APPLICATION'])
prev_app2.loc[:, 'AMT_CREDIT'] = np.log1p(prev_app2['AMT_CREDIT'])
prev_app2.loc[:, 'AMT_GOODS_PRICE'] = np.log1p(prev_app2['AMT_GOODS_PRICE'])

# %%
prev_app2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 536201 entries, 5 to 1670212
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   SK_ID_PREV                   536201 non-null  int64
#  1   SK_ID_CURR                   536201 non-null  int64
#  2   NAME_CONTRACT_TYPE           536201 non-null  object
#  3   AMT_ANNUITY                  536201 non-null  float64
#  4   AMT_APPLICATION              536201 non-null  float64
#  5   AMT_CREDIT                   536201 non-null  float64
#  6   AMT_DOWN_PAYMENT             536201 non-null  float64
#  7   AMT_GOODS_PRICE              536201 non-null  float64
#  8   WEEKDAY_APPR_PROCESS_START   536201 non-null  object
#  9   HOUR_APPR_PROCESS_START      536201 non-null  int64
#  10  FLAG_LAST_APPL_PER_CONTRACT  536201 non-null  object
#  11  NFLAG_LAST_APPL_IN_DAY       536201 non-null  int64
# ...

# %%
prev_app2.describe()
# Out:
#          SK_ID_PREV     SK_ID_CURR    AMT_ANNUITY  AMT_APPLICATION  \
# count  5.362010e+05  536201.000000  536201.000000    536201.000000
# mean   1.946213e+06  278349.692140       9.346844         4.191001
# std    5.280987e+05  102863.277826       0.408874         5.673120
# min    1.000027e+06  100005.000000       0.000000         0.000000
# 25%    1.503161e+06  189264.000000       9.328212         0.000000
# 50%    1.957965e+06  278789.000000       9.328212         0.000000
# 75%    2.400852e+06  367655.000000       9.328212        11.441784
# max    2.845363e+06  456255.000000      10.333147        12.911645
#
#           AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# count  536201.000000          536201.0    536201.000000
# mean        4.476077               0.0        11.605624
# std         5.795932               0.0         1.132906
# min         0.000000               0.0         0.000000
# 25%         0.000000               0.0        11.629116
# ...

# %% [markdown]
# #### E. Feature Encoding

# %%
#Buat semua kategorikal features one hot encoding
prev_app_encoded = pd.get_dummies(prev_app2, drop_first=False)

# Convert boolean columns from True/False to 1/0
prev_app_encoded = prev_app_encoded.astype(int)

# Display the first few rows to confirm the changes
prev_app_encoded.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR  AMT_ANNUITY  AMT_APPLICATION  AMT_CREDIT  \
# 5     1383531      199383           10               12          12
# 6     2315218      175704            9                0           0
# 7     1656711      296299            9                0           0
# 8     2367563      342292            9                0           0
# 9     2579447      334349            9                0           0
#
#    AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  HOUR_APPR_PROCESS_START  \
# 5                 0               12                        8
# 6                 0               11                       11
# 7                 0               11                        7
# 8                 0               11                       15
# 9                 0               11                       15
#
#    NFLAG_LAST_APPL_IN_DAY  RATE_DOWN_PAYMENT  RATE_INTEREST_PRIMARY  \
# 5                       1                  0                      0
# ...

# %%
#Check kembali missing value setelah transformation
check_missing_values(prev_app_encoded)
# Out:
# Tidak ada missing value di dataset.

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# #### A. Feature Selection

# %%
#Drop feature yang normalized dan SK_ID_CURR 
col_remove = ['RATE_DOWN_PAYMENT', 'RATE_INTEREST_PRIMARY', 'RATE_INTEREST_PRIVILEGED']

prev_app_encoded.drop(col_remove, axis=1, inplace=True)

# %%
prev_app_encoded.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR  AMT_ANNUITY  AMT_APPLICATION  AMT_CREDIT  \
# 5     1383531      199383           10               12          12
# 6     2315218      175704            9                0           0
# 7     1656711      296299            9                0           0
# 8     2367563      342292            9                0           0
# 9     2579447      334349            9                0           0
#
#    AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  HOUR_APPR_PROCESS_START  \
# 5                 0               12                        8
# 6                 0               11                       11
# 7                 0               11                        7
# 8                 0               11                       15
# 9                 0               11                       15
#
#    NFLAG_LAST_APPL_IN_DAY  DAYS_DECISION  SELLERPLACE_AREA  CNT_PAYMENT  \
# 5                       1              0                -1           18
# ...

# %% [markdown]
# **Menentukan Features yang penting dengan cara korelasi antar Features dan korelasi Features terhadap Target**

# %%
#merge data terbaru dengan df_train
merge_df2 = pd.merge(prev_app_encoded, df_train[['SK_ID_CURR', 'TARGET']], on='SK_ID_CURR', how='inner')

merge_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445897 entries, 0 to 445896
# Columns: 149 entries, SK_ID_PREV to TARGET
# dtypes: int32(148), int64(1)
# memory usage: 255.1 MB

# %%
# Menghitung matriks korelasi
corr_matrix = merge_df2.corr().abs()

# Menentukan threshold korelasi
threshold = 0.7

# Memilih pasangan fitur yang memiliki korelasi lebih tinggi dari threshold
upper_triangle = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
features_to_drop = [column for column in upper_triangle.columns if any(upper_triangle[column] > threshold)]

# Menghapus fitur yang memiliki korelasi tinggi
prev_app_reduced = merge_df2.drop(columns=features_to_drop)

print("Fitur yang dihapus karena multikolinearitas:", features_to_drop)
print("Jumlah fitur setelah penghapusan:", prev_app_reduced.shape[1])
# Out:
# Fitur yang dihapus karena multikolinearitas: ['AMT_CREDIT', 'DAYS_LAST_DUE_1ST_VERSION', 'DAYS_LAST_DUE', 'NAME_CONTRACT_TYPE_Revolving loans', 'FLAG_LAST_APPL_PER_CONTRACT_N', 'FLAG_LAST_APPL_PER_CONTRACT_Y', 'NAME_CASH_LOAN_PURPOSE_XAP', 'NAME_CASH_LOAN_PURPOSE_XNA', 'NAME_CONTRACT_STATUS_Approved', 'NAME_CONTRACT_STATUS_Canceled', 'NAME_PAYMENT_TYPE_Cash through the bank', 'NAME_PAYMENT_TYPE_XNA', 'CODE_REJECT_REASON_CLIENT', 'CODE_REJECT_REASON_HC', 'CODE_REJECT_REASON_XAP', 'NAME_TYPE_SUITE_Unaccompanied', 'NAME_CLIENT_TYPE_Repeater', 'NAME_GOODS_CATEGORY_XNA', 'NAME_PORTFOLIO_Cash', 'NAME_PORTFOLIO_XNA', 'NAME_PRODUCT_TYPE_XNA', 'NAME_PRODUCT_TYPE_x-sell', 'NAME_SELLER_INDUSTRY_Connectivity', 'NAME_SELLER_INDUSTRY_XNA', 'NAME_YIELD_GROUP_XNA', 'PRODUCT_COMBINATION_Card Street', 'PRODUCT_COMBINATION_Cash', 'PRODUCT_COMBINATION_Cash X-Sell: low', 'PRODUCT_COMBINATION_Cash X-Sell: middle', 'PRODUCT_COMBINATION_POS household with interest', 'PRODUCT_COMBINATION_POS mobile with inte
# ...

# %%
prev_app_reduced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445897 entries, 0 to 445896
# Columns: 118 entries, SK_ID_PREV to TARGET
# dtypes: int32(117), int64(1)
# memory usage: 202.4 MB

# %%
# Correlation matrix
corr_matrix2 = prev_app_reduced.corr()

# Heatmap of the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Menghitung korelasi antara setiap fitur dan target
correlation_with_target = prev_app_reduced.corr()['TARGET'].abs().sort_values(ascending=False)

# Menentukan threshold korelasi (misalnya 0.05)
threshold = 0.05

# Memilih fitur yang memiliki korelasi absolut di atas threshold
selected_features = correlation_with_target[correlation_with_target > threshold].index.tolist()
selected_features.extend(['SK_ID_CURR', 'SK_ID_PREV'])

# Menghapus duplikat jika ada
selected_features = list(set(selected_features))

# Menampilkan daftar fitur yang dipilih
print(f"Fitur yang dipilih (di atas threshold {threshold}):")
print(selected_features)
# Out:
# Fitur yang dipilih (di atas threshold 0.05):
# ['SK_ID_PREV', 'TARGET', 'NAME_PRODUCT_TYPE_walk-in', 'SK_ID_CURR', 'NAME_CONTRACT_STATUS_Refused', 'CODE_REJECT_REASON_SCOFR']

# %% [markdown]
# #### B. Feature Extraction

# %%
# Filter dataset berdasarkan fitur yang dipilih
filtered_df = merge_df2[selected_features]

filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445897 entries, 0 to 445896
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   SK_ID_PREV                    445897 non-null  int32
#  1   TARGET                        445897 non-null  int64
#  2   NAME_PRODUCT_TYPE_walk-in     445897 non-null  int32
#  3   SK_ID_CURR                    445897 non-null  int32
#  4   NAME_CONTRACT_STATUS_Refused  445897 non-null  int32
#  5   CODE_REJECT_REASON_SCOFR      445897 non-null  int32
# dtypes: int32(5), int64(1)
# memory usage: 11.9 MB

# %%
ordered_columns = ['SK_ID_PREV', 'SK_ID_CURR'] + [col for col in filtered_df.columns if col not in ['SK_ID_PREV', 'SK_ID_CURR', 'TARGET']] + ['TARGET']

# Mengatur urutan kolom dalam DataFrame
filtered_df = filtered_df[ordered_columns]

# Menampilkan DataFrame hasil
filtered_df.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR  NAME_PRODUCT_TYPE_walk-in  \
# 0     1383531      199383                          0
# 1     2315218      175704                          0
# 2     1656711      296299                          0
# 3     2367563      342292                          0
# 4     2579447      334349                          0
#
#    NAME_CONTRACT_STATUS_Refused  CODE_REJECT_REASON_SCOFR  TARGET
# 0                             0                         0       0
# 1                             0                         0       0
# 2                             0                         0       0
# 3                             0                         0       0
# 4                             0                         0       0

# %% [markdown]
# #### C. Additional Features

# %%
# Contoh data tambahan yang mungkin diperlukan
application_data = pd.read_csv('application_train.csv')

# 1. Loan-to-Value Ratio (LTV)
prev_app['LTV'] = prev_app['AMT_CREDIT'] / prev_app['AMT_GOODS_PRICE']

# 2. Debt-to-Income Ratio (DTI)
previous_application = prev_app.merge(application_data[['SK_ID_CURR', 'AMT_INCOME_TOTAL']], on='SK_ID_CURR', how='left')
previous_application['DTI'] = previous_application['AMT_CREDIT'] / previous_application['AMT_INCOME_TOTAL']

# 3. Credit Utilization Rate
credit_card_balance = pd.read_csv('credit_card_balance.csv')
credit_card_balance['CREDIT_UTILIZATION'] = credit_card_balance['AMT_BALANCE'] / credit_card_balance['AMT_CREDIT_LIMIT_ACTUAL']
credit_utilization = credit_card_balance.groupby('SK_ID_CURR')['CREDIT_UTILIZATION'].mean().reset_index()
previous_application2 = prev_app.merge(credit_utilization, on='SK_ID_CURR', how='left')

# 4. Employment Stability
application_data['YEARS_EMPLOYED'] = application_data['DAYS_EMPLOYED'] / -365
previous_application3 = prev_app.merge(application_data[['SK_ID_CURR', 'YEARS_EMPLOYED']], on='SK_ID_CURR', how='left')

# 5. Previous Loan Performance
prev_app['LOAN_PERFORMANCE'] = prev_app['DAYS_LAST_DUE'] / prev_app['CNT_PAYMENT']

# %%
filtered_df.to_csv('Previous Application_PreProcessing FIX.csv', index = False)
